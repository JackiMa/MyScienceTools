# %%
from modules import *
# Out:
# 导入了模块：lecory_data_process, lecroy, myInterpolation

# %%
fileName = r'spectrum\QE\QE_R6233_RL0840.csv'
QE_R6233 = myInterpolation(ReadData(fileName),plot=True,smooth_window=1).process()

fileName = r'spectrum\QE\QE_S3590.csv'
QE_S359008 = myInterpolation(ReadData(fileName),plot=True,smooth_window=1).process()

fileName = r'spectrum\scintillator_实测\Em_GAGG.txt'
EM_GAGG = myInterpolation(ReadData(fileName),plot=True,smooth_window=1).process()

fileName = r'spectrum\scintillator_实测\Em_BGO777.txt'
EM_BGO = myInterpolation(ReadData(fileName),plot=True,smooth_window=1).process()

fileName = r'spectrum\scintillator_web\Em_CsI(Tl)_web.txt'
EM_CsI = myInterpolation(ReadData(fileName),plot=True,smooth_window=1).process()

fileName = r'spectrum\scintillator_web\Em_LYSO_web.txt'
EM_LYSO = myInterpolation(ReadData(fileName),plot=True,smooth_window=1).process()
# Out:
# Successfully auto read spectrum\QE\QE_R6233_RL0840.csv using separator '	', data shape is (41, 2)
# Successfully auto read spectrum\QE\QE_S3590.csv using separator ',', data shape is (1000, 2)
# Successfully auto read spectrum\scintillator_实测\Em_GAGG.txt using separator ',', data shape is (71, 3)
# Successfully auto read spectrum\scintillator_实测\Em_BGO777.txt using separator ',', data shape is (251, 3)
# Successfully auto read spectrum\scintillator_web\Em_CsI(Tl)_web.txt using separator ',', data shape is (136, 2)
# Successfully auto read spectrum\scintillator_web\Em_LYSO_web.txt using separator ',', data shape is (68, 2)

# %%
calculate_weighted_average(EM_GAGG, QE_R6233)
calculate_weighted_average(EM_CsI, QE_R6233)
calculate_weighted_average(EM_BGO, QE_R6233)
calculate_weighted_average(EM_LYSO, QE_R6233)

calculate_weighted_average(EM_GAGG, QE_S359008)
calculate_weighted_average(EM_CsI, QE_S359008)
calculate_weighted_average(EM_BGO, QE_S359008)
calculate_weighted_average(EM_LYSO, QE_S359008)
# Out:
# The average of QE_R6233_RL0840 weighted by Em_GAGG is: 13.467623300827658
# The average of QE_R6233_RL0840 weighted by Em_CsI(Tl)_web is: 13.739323074078536
# The average of QE_R6233_RL0840 weighted by Em_BGO777 is: 20.165139500872122
# The average of QE_R6233_RL0840 weighted by Em_LYSO_web is: 29.576908887124496
# The average of QE_S3590 weighted by Em_GAGG is: 0.8689543035625983
# The average of QE_S3590 weighted by Em_CsI(Tl)_web is: 0.8645318577457034
# The average of QE_S3590 weighted by Em_BGO777 is: 0.8286311611975365
# The average of QE_S3590 weighted by Em_LYSO_web is: 0.7647964591275707
# 0.7647964591275707
